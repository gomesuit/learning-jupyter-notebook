# %%
from numpy.random import randn
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set()

# %%
import numpy as np

x = np.linspace(0, 10, 100)

y = x + np.random.randn(100)

plt.plot(x, y)
plt.show()

# %%
# 散布図

plt.scatter(x, y)
plt.show()

# %%
# ヒストグラム
plt.hist(np.random.randn(1000), bins=10)
plt.show()

# %%
# 色

target = np.array([0 for i in range(50)] + [1 for i in range(50)])

# %%
plt.scatter(x, y, c=target)
plt.show()

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 2.,  3.,  3., 12., 13., 18., 23., 15.,  5.,  6.]),
#  array([-2.58204993, -2.10250182, -1.6229537 , -1.14340559, -0.66385748,
#         -0.18430936,  0.29523875,  0.77478686,  1.25433498,  1.73388309,
#          2.2134312 ]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)
plt.hist(dataset2)
# Out:
# (array([ 2.,  4.,  6., 11., 18., 13.,  8.,  8.,  5.,  5.]),
#  array([-2.21739804, -1.79581428, -1.37423053, -0.95264677, -0.53106301,
#         -0.10947925,  0.31210451,  0.73368827,  1.15527203,  1.57685578,
#          1.99843954]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1, density=True, alpha=0.5, bins=20)
plt.hist(dataset2, density=True, alpha=0.5, bins=20, color='indianred')
# Out:
# (array([0.0593002 , 0.0593002 , 0.0593002 , 0.17790059, 0.17790059,
#         0.17790059, 0.35580118, 0.29650099, 0.53370177, 0.53370177,
#         0.53370177, 0.23720079, 0.17790059, 0.29650099, 0.29650099,
#         0.17790059, 0.29650099, 0.        , 0.0593002 , 0.23720079]),
#  array([-2.21739804, -2.00660616, -1.79581428, -1.58502241, -1.37423053,
#         -1.16343865, -0.95264677, -0.74185489, -0.53106301, -0.32027113,
#         -0.10947925,  0.10131263,  0.31210451,  0.52289639,  0.73368827,
#          0.94448015,  1.15527203,  1.3660639 ,  1.57685578,  1.78764766,
#          1.99843954]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(x=data1, y=data2)

# %%
sns.jointplot(x=data1, y=data2, kind='hex')

# %%
flight_dframe = sns.load_dataset('flights')
flight_dframe.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_dframe = flight_dframe.pivot('month', 'year', 'passengers')

# %%
flight_dframe
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(flight_dframe)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(flight_dframe, annot=True, fmt='d')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(flight_dframe, center=flight_dframe.loc['Jan', 1955])
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
import pandas as pd

f, (axis1, axis2) = plt.subplots(2, 1)

yearly_flights = flight_dframe.sum()

years = pd.Series(yearly_flights.index.values)
years = pd.DataFrame(years)

flights = pd.Series(yearly_flights.values)
flights = pd.DataFrame(flights)

year_dframe = pd.concat((years, flights), axis=1)
year_dframe.columns = ['Year', 'Flights']

sns.barplot('Year', y='Flights', data=year_dframe, ax=axis1)
sns.heatmap(flight_dframe, cmap='Blues', ax=axis2, cbar_kws={'orientation':'horizontal'})
# Out:
# /Users/takashi/.local/share/virtualenvs/learning-jupyter-notebook-Tv03RnbL/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(flight_dframe)

# %%
sns.clustermap(flight_dframe, col_cluster=False)

# %%
sns.clustermap(flight_dframe, standard_scale=1)

# %%
sns.clustermap(flight_dframe, standard_scale=0)

# %%
sns.clustermap(flight_dframe, z_score=1)
